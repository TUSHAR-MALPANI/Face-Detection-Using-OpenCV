# %%
import numpy as np
import cv2

# %%
img = cv2.imread('faces.jpg')
cv2.imshow('faces',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
# step 1: convert image into gray scale
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# step 2: apply cascade classifier on gray scale image
box , dimensions = face_cascade.detectMultiScale2(img,minNeighbors = 6)

# %%
box
# Out:
# array([[321,  84, 385, 385],
#        [697, 107, 248, 248],
#        [ 88,  75, 316, 316]])

# %%
# 321,84 is the x and y position and 385,385 is the width and height of the box(width and height of face) 
# 88,75 is the x and y position and 316,316 is the width and height of the box(width and height of face) 
# 697,107 is the x and y position and 248,248 is the width and height of the box(width and height of face)

# %%
detections
# Out:
# array([35, 10, 37])

# %%
# step 3: draw boundary box
image = img.copy()
for x,y,w,h in box:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),1)    # (x,y),(x+w,y+h) are diagonal points of a box 

cv2.imshow('face detection',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
